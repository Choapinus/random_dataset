# %%
import bokeh
import numpy as np
import pandas as pd
from bokeh.io import output_notebook

output_notebook()
# https://bokeh.pydata.org/en/latest/docs/gallery.html
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# # Obj 01: Aumento sostenido de clientes nuevos

# %%
df_clientes = pd.read_csv('../datasets/clientes.csv')
df_clientes = df_clientes.set_index('index')
df_clientes.fecha_creacion = df_clientes['fecha_creacion'].apply(pd.Timestamp)
df_clientes.fecha_ultima_compra = df_clientes.fecha_ultima_compra.apply(pd.Timestamp)
df_clientes.fecha_ultima_devolucion = df_clientes.fecha_ultima_devolucion.apply(pd.Timestamp)
df_clientes.head()
# Out:
#       fecha_creacion fecha_ultima_compra fecha_ultima_devolucion  \
# index
# 0         2000-06-08          2008-11-11              2003-04-04
# 1         2012-08-29          2017-10-10              2005-08-06
# 2         2014-03-10          2016-09-25              2016-01-14
# 3         2012-05-20          2015-01-27              2006-04-10
# 4         2005-03-16          2010-09-12              2003-04-07
#
#        total_compras  cantidad_devoluciones
# index
# 0                297                     40
# 1                372                     19
# 2                405                     28
# 3                411                     38
# 4                336                     19

# %%
from bokeh.io import show, output_file
from bokeh.models import FactorRange
from bokeh.plotting import figure

output_file("../graphs/obj01_aumento_clientes.html")

factors = [ str(i) for i in range(df.min().item(), df.max().item()) ] # años

p = figure(x_range=FactorRange(*factors), plot_height=350,
           toolbar_location=None, tools="")

x = [] # cant clientes

for i in factors:
    cl = df_clientes[df_clientes.fecha_creacion.dt.year <= np.int32(i)].fecha_creacion.count()
    x.append(cl)


p.vbar(x=factors, top=x, width=0.9, alpha=0.5)

p.line(x=[ str(i) for i in factors ], y=[ i//1.5 for i in clientes ], color="red", line_width=2)

p.y_range.start = 0
p.x_range.range_padding = 0.1
p.xaxis.major_label_orientation = 1
p.xgrid.grid_line_color = None

show(p)
# Out:
#   <div class="bk-root" id="15ffe4f5-2c2b-437a-a1d0-9e5aa28ac7c4" data-root-id="2303"></div>

# %% [markdown]
# # Obj 02: Aumentar las ventas

# %%
df_costos = pd.read_csv('../datasets/costos_mensuales.csv')
df_costos = df_costos.set_index('index')
df_costos.head()
# Out:
#        gastos_admin  gastos_no_operacionales  arriendos fecha_mensual
# index
# 0           6421412                  2329026   86437965    2000-01-11
# 1           2411213                  1684829   79346109    2000-02-25
# 2           3537121                  8723023   14416641    2000-03-01
# 3           8422620                  9391497   25032375    2000-04-18
# 4           4608048                  7956444   77667153    2000-05-07

# %%
df_empleados = pd.read_csv('../datasets/empleados.csv')
df_empleados = df_empleados.set_index('index')
df_empleados['fecha_ingreso'] = df_empleados['fecha_ingreso'].apply(pd.Timestamp)
df_empleados.head()
# Out:
#                                nombre      cargo  sueldo fecha_ingreso  \
# index
# 0                       Carlos Posada  Seguridad  642912    2016-04-26
# 1          Daniel María José Elizondo  Reponedor  461941    2012-05-14
# 2          Jorge Luis Armenta Badillo  Seguridad  611941    2016-05-04
# 3      Manuel Amador Ontiveros Ocasio     Cajero  592912    2017-07-15
# 4                  Aurelio Frida Orta  Reponedor  430970    2017-08-17
#
#       fecha_desvinculacion  horas_trabajadas
# index
# 0               2017-08-06              9774
# 1               2015-07-13             20484
# 2               2017-08-24              9702
# 3               2017-09-28              5769
# 4               2017-11-07              5472

# %%
df_productos = pd.read_csv('../datasets/productos.csv')
df_productos = df_productos.set_index('index')
df_productos.head()
# Out:
#                nombre categoria  precio
# index
# 0      Exercitationem   Chandal   73000
# 1             Tempora   Chandal   55000
# 2                  Ea  Camiseta   64000
# 3             Placeat    Jersey   55000
# 4               Rerum  Camiseta   98000

# %%
df_ratings = pd.read_csv('../datasets/ratings.csv')
df_ratings = df_ratings.set_index('index')
df_ratings.head()
# Out:
#        cant_estrellas                                        comentarios
# index
# 0                   8  Corporis saepe beatae aliquid reiciendis harum...
# 1                   6  Accusantium laboriosam iure architecto repelle...
# 2                   2  Eveniet quasi rem quis. Repudiandae sit alias ...
# 3                   3  Quos autem assumenda totam at. Vel fugiat sapi...
# 4                   2  Perspiciatis consequuntur explicabo accusantiu...

# %%
df_sucursales = pd.read_csv('../datasets/sucursales.csv')
df_sucursales = df_sucursales.set_index('index')
df_sucursales.head()
# Out:
#                        direccion                region  tiempo_offline_horas
# index
# 0              At deserunt nulla              V Region                     0
# 1      Similique facere corporis           VIII Region                     0
# 2            Rem possimus dolore  Region Metropolitana                     0
# 3         https://tallawrande.cl              V Region                    27
# 4         https://tallawrande.cl           VIII Region                     7
